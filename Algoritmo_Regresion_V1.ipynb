# %% [markdown]
# <a href="https://colab.research.google.com/github/SilverFoxMedia-Tesis/IA_01/blob/main/Algoritmo_Regresion_V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Lectura de datos
train = pd.read_csv('/ObesityDataSet_raw_and_data_sinthetic.csv')
test = pd.read_csv('/ObesityDataSet_raw_and_data_sinthetic.csv')

# %%
train.head(10)
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
# 5    Male  29.0    1.62    53.0                             no  yes   2.0
# 6  Female  23.0    1.50    55.0                            yes  yes   3.0
# 7    Male  22.0    1.64    53.0                             no   no   2.0
# 8    Male  24.0    1.78    64.0                            yes  yes   3.0
# 9    Male  22.0    1.72    68.0                            yes  yes   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# ...

# %%
train[['Height','Weight']].head(10)
# Out:
#    Height  Weight
# 0    1.62    64.0
# 1    1.52    56.0
# 2    1.80    77.0
# 3    1.80    87.0
# 4    1.78    89.8
# 5    1.62    53.0
# 6    1.50    55.0
# 7    1.64    53.0
# 8    1.78    64.0
# 9    1.72    68.0
